# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm 
import os
import glob
from re import I
import pandas as pd
import numpy as np
import natsort
import datetime
import json
import matplotlib
import matplotlib.pyplot as plt
import umap.umap_ as umap
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans
from collections import Counter
from sklearn.preprocessing import MinMaxScaler, StandardScaler
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Pathを通す

# %%
# Path
cwd = os.path.join(os.getcwd() + "/Data")
save_path = os.path.join(os.getcwd() + "/analysis_results")

S1_path = os.path.join(cwd, 'S1')
S2_path = os.path.join(cwd, 'S2')
S3_path = os.path.join(cwd, 'S3')
S4_path = os.path.join(cwd, 'S4')
S5_path = os.path.join(cwd, 'S5')
S6_path = os.path.join(cwd, 'S6')
S7_path = os.path.join(cwd, 'S7')
S8_path = os.path.join(cwd, 'S8')
S9_path = os.path.join(cwd, 'S9')
S10_path = os.path.join(cwd, 'S10')

S1_M1 = '{}/Midterm1/'.format(S1_path)
S2_M1 = '{}/Midterm1/'.format(S2_path)
S3_M1 = '{}/Midterm1/'.format(S3_path)
S4_M1 = '{}/Midterm1/'.format(S4_path)
S5_M1 = '{}/Midterm1/'.format(S5_path)
S6_M1 = '{}/Midterm1/'.format(S6_path)
S7_M1 = '{}/Midterm1/'.format(S7_path)
S8_M1 = '{}/Midterm1/'.format(S8_path)
S9_M1 = '{}/Midterm1/'.format(S9_path)
S10_M1 = '{}/Midterm1/'.format(S10_path)

S1_M2 = '{}/Midterm2/'.format(S1_path)
S2_M2 = '{}/Midterm2/'.format(S2_path)
S3_M2 = '{}/Midterm2/'.format(S3_path)
S4_M2 = '{}/Midterm2/'.format(S4_path)
S5_M2 = '{}/Midterm2/'.format(S5_path)
S6_M2 = '{}/Midterm2/'.format(S6_path)
S7_M2 = '{}/Midterm2/'.format(S7_path)
S8_M2 = '{}/Midterm2/'.format(S8_path)
S9_M2 = '{}/Midterm2/'.format(S9_path)
S10_M2 = '{}/Midterm2/'.format(S10_path)

S1_F = '{}/Final/'.format(S1_path)
S2_F = '{}/Final/'.format(S2_path)
S3_F = '{}/Final/'.format(S3_path)
S4_F = '{}/Final/'.format(S4_path)
S5_F = '{}/Final/'.format(S5_path)
S6_F = '{}/Final/'.format(S6_path)
S7_F = '{}/Final/'.format(S7_path)
S8_F = '{}/Final/'.format(S8_path)
S9_F = '{}/Final/'.format(S9_path)
S10_F = '{}/Final/'.format(S10_path)

# %% [markdown]
# ### データセットの読み込み

# %%
S1_Final_ACC = pd.read_csv("{}ACC.csv".format(S1_F))
S1_Final_EDA = pd.read_csv("{}EDA.csv".format(S1_F))
S1_Final_HR = pd.read_csv("{}HR.csv".format(S1_F))
S1_Final_TEMP = pd.read_csv("{}TEMP.csv".format(S1_F))

S2_Final_ACC = pd.read_csv("{}ACC.csv".format(S2_F))
S2_Final_EDA = pd.read_csv("{}EDA.csv".format(S2_F))
S2_Final_HR = pd.read_csv("{}HR.csv".format(S2_F))
S2_Final_TEMP = pd.read_csv("{}TEMP.csv".format(S2_F))

S3_Final_ACC = pd.read_csv("{}ACC.csv".format(S3_F))
S3_Final_EDA = pd.read_csv("{}EDA.csv".format(S3_F))
S3_Final_HR = pd.read_csv("{}HR.csv".format(S3_F))
S3_Final_TEMP = pd.read_csv("{}TEMP.csv".format(S3_F))

S4_Final_ACC = pd.read_csv("{}ACC.csv".format(S4_F))
S4_Final_EDA = pd.read_csv("{}EDA.csv".format(S4_F))
S4_Final_HR = pd.read_csv("{}HR.csv".format(S4_F))
S4_Final_TEMP = pd.read_csv("{}TEMP.csv".format(S4_F))

S5_Final_ACC = pd.read_csv("{}ACC.csv".format(S5_F))
S5_Final_EDA = pd.read_csv("{}EDA.csv".format(S5_F))
S5_Final_HR = pd.read_csv("{}HR.csv".format(S5_F))
S5_Final_TEMP = pd.read_csv("{}TEMP.csv".format(S5_F))

S6_Final_ACC = pd.read_csv("{}ACC.csv".format(S6_F))
S6_Final_EDA = pd.read_csv("{}EDA.csv".format(S6_F))
S6_Final_HR = pd.read_csv("{}HR.csv".format(S6_F))
S6_Final_TEMP = pd.read_csv("{}TEMP.csv".format(S6_F))

S7_Final_ACC = pd.read_csv("{}ACC.csv".format(S7_F))
S7_Final_EDA = pd.read_csv("{}EDA.csv".format(S7_F))
S7_Final_HR = pd.read_csv("{}HR.csv".format(S7_F))
S7_Final_TEMP = pd.read_csv("{}TEMP.csv".format(S7_F))

S8_Final_ACC = pd.read_csv("{}ACC.csv".format(S8_F))
S8_Final_EDA = pd.read_csv("{}EDA.csv".format(S8_F))
S8_Final_HR = pd.read_csv("{}HR.csv".format(S8_F))
S8_Final_TEMP = pd.read_csv("{}TEMP.csv".format(S8_F))

S9_Final_ACC = pd.read_csv("{}ACC.csv".format(S9_F))
S9_Final_EDA = pd.read_csv("{}EDA.csv".format(S9_F))
S9_Final_HR = pd.read_csv("{}HR.csv".format(S9_F))
S9_Final_TEMP = pd.read_csv("{}TEMP.csv".format(S9_F))

S10_Final_ACC = pd.read_csv("{}ACC.csv".format(S10_F))
S10_Final_EDA = pd.read_csv("{}EDA.csv".format(S10_F))
S10_Final_HR = pd.read_csv("{}HR.csv".format(S10_F))
S10_Final_TEMP = pd.read_csv("{}TEMP.csv".format(S10_F))

# %% [markdown]
# ## ACCの統計情報

# %%
S1_Final_ACC = S1_Final_ACC.set_axis(['x_axis', 'y_axis', 'z_axis'], axis = 1)
S2_Final_ACC = S2_Final_ACC.set_axis(['x_axis', 'y_axis', 'z_axis'], axis = 1)
S3_Final_ACC = S3_Final_ACC.set_axis(['x_axis', 'y_axis', 'z_axis'], axis = 1)
S4_Final_ACC = S4_Final_ACC.set_axis(['x_axis', 'y_axis', 'z_axis'], axis = 1)
S5_Final_ACC = S5_Final_ACC.set_axis(['x_axis', 'y_axis', 'z_axis'], axis = 1)
S6_Final_ACC = S6_Final_ACC.set_axis(['x_axis', 'y_axis', 'z_axis'], axis = 1)
S7_Final_ACC = S7_Final_ACC.set_axis(['x_axis', 'y_axis', 'z_axis'], axis = 1)
S8_Final_ACC = S8_Final_ACC.set_axis(['x_axis', 'y_axis', 'z_axis'], axis = 1)
S9_Final_ACC = S9_Final_ACC.set_axis(['x_axis', 'y_axis', 'z_axis'], axis = 1)
S10_Final_ACC = S10_Final_ACC.set_axis(['x_axis', 'y_axis', 'z_axis'], axis = 1)

# %%
S1_Final_ACC = S1_Final_ACC.drop(S1_Final_ACC.index[[0]])
S2_Final_ACC = S2_Final_ACC.drop(S2_Final_ACC.index[[0]])
S3_Final_ACC = S3_Final_ACC.drop(S3_Final_ACC.index[[0]])
S4_Final_ACC = S4_Final_ACC.drop(S4_Final_ACC.index[[0]])
S5_Final_ACC = S5_Final_ACC.drop(S5_Final_ACC.index[[0]])
S6_Final_ACC = S6_Final_ACC.drop(S6_Final_ACC.index[[0]])
S7_Final_ACC = S7_Final_ACC.drop(S7_Final_ACC.index[[0]])
S8_Final_ACC = S8_Final_ACC.drop(S8_Final_ACC.index[[0]])
S9_Final_ACC = S9_Final_ACC.drop(S9_Final_ACC.index[[0]])
S10_Final_ACC = S10_Final_ACC.drop(S10_Final_ACC.index[[0]])

# %%
ACC_x_max =[]
for num in [S1_Final_ACC, S2_Final_ACC, S3_Final_ACC, S4_Final_ACC, S5_Final_ACC, S6_Final_ACC, 
            S7_Final_ACC, S8_Final_ACC, S9_Final_ACC, S10_Final_ACC]:
    ACC_x_max.append(num['x_axis'].max())

ACC_x_min =[]
for num in [S1_Final_ACC, S2_Final_ACC, S3_Final_ACC, S4_Final_ACC, S5_Final_ACC, S6_Final_ACC, 
            S7_Final_ACC, S8_Final_ACC, S9_Final_ACC, S10_Final_ACC]:
    ACC_x_min.append(num['x_axis'].min())

ACC_x_mean =[]
for num in [S1_Final_ACC, S2_Final_ACC, S3_Final_ACC, S4_Final_ACC, S5_Final_ACC, S6_Final_ACC, 
            S7_Final_ACC, S8_Final_ACC, S9_Final_ACC, S10_Final_ACC]:
    ACC_x_mean.append(num['x_axis'].mean())

ACC_x_std =[]
for num in [S1_Final_ACC, S2_Final_ACC, S3_Final_ACC, S4_Final_ACC, S5_Final_ACC, S6_Final_ACC, 
            S7_Final_ACC, S8_Final_ACC, S9_Final_ACC, S10_Final_ACC]:
    ACC_x_std.append(num['x_axis'].std())

ACC_x_median =[]
for num in [S1_Final_ACC, S2_Final_ACC, S3_Final_ACC, S4_Final_ACC, S5_Final_ACC, S6_Final_ACC, 
            S7_Final_ACC, S8_Final_ACC, S9_Final_ACC, S10_Final_ACC]:
    ACC_x_median.append(num['x_axis'].mean())

# %%
ACC_y_max =[]
for num in [S1_Final_ACC, S2_Final_ACC, S3_Final_ACC, S4_Final_ACC, S5_Final_ACC, S6_Final_ACC, 
            S7_Final_ACC, S8_Final_ACC, S9_Final_ACC, S10_Final_ACC]:
    ACC_y_max.append(num['x_axis'].max())

ACC_y_min =[]
for num in [S1_Final_ACC, S2_Final_ACC, S3_Final_ACC, S4_Final_ACC, S5_Final_ACC, S6_Final_ACC, 
            S7_Final_ACC, S8_Final_ACC, S9_Final_ACC, S10_Final_ACC]:
    ACC_y_min.append(num['x_axis'].min())

ACC_y_mean =[]
for num in [S1_Final_ACC, S2_Final_ACC, S3_Final_ACC, S4_Final_ACC, S5_Final_ACC, S6_Final_ACC, 
            S7_Final_ACC, S8_Final_ACC, S9_Final_ACC, S10_Final_ACC]:
    ACC_y_mean.append(num['x_axis'].mean())

ACC_y_std =[]
for num in [S1_Final_ACC, S2_Final_ACC, S3_Final_ACC, S4_Final_ACC, S5_Final_ACC, S6_Final_ACC, 
            S7_Final_ACC, S8_Final_ACC, S9_Final_ACC, S10_Final_ACC]:
    ACC_y_std.append(num['x_axis'].std())

ACC_y_median =[]
for num in [S1_Final_ACC, S2_Final_ACC, S3_Final_ACC, S4_Final_ACC, S5_Final_ACC, S6_Final_ACC, 
            S7_Final_ACC, S8_Final_ACC, S9_Final_ACC, S10_Final_ACC]:
    ACC_y_median.append(num['x_axis'].mean())

# %%
ACC_z_max =[]
for num in [S1_Final_ACC, S2_Final_ACC, S3_Final_ACC, S4_Final_ACC, S5_Final_ACC, S6_Final_ACC, 
            S7_Final_ACC, S8_Final_ACC, S9_Final_ACC, S10_Final_ACC]:
    ACC_z_max.append(num['x_axis'].max())

ACC_z_min =[]
for num in [S1_Final_ACC, S2_Final_ACC, S3_Final_ACC, S4_Final_ACC, S5_Final_ACC, S6_Final_ACC, 
            S7_Final_ACC, S8_Final_ACC, S9_Final_ACC, S10_Final_ACC]:
    ACC_z_min.append(num['x_axis'].min())

ACC_z_mean =[]
for num in [S1_Final_ACC, S2_Final_ACC, S3_Final_ACC, S4_Final_ACC, S5_Final_ACC, S6_Final_ACC, 
            S7_Final_ACC, S8_Final_ACC, S9_Final_ACC, S10_Final_ACC]:
    ACC_z_mean.append(num['x_axis'].mean())

ACC_z_std =[]
for num in [S1_Final_ACC, S2_Final_ACC, S3_Final_ACC, S4_Final_ACC, S5_Final_ACC, S6_Final_ACC, 
            S7_Final_ACC, S8_Final_ACC, S9_Final_ACC, S10_Final_ACC]:
    ACC_z_std.append(num['x_axis'].std())

ACC_z_median =[]
for num in [S1_Final_ACC, S2_Final_ACC, S3_Final_ACC, S4_Final_ACC, S5_Final_ACC, S6_Final_ACC, 
            S7_Final_ACC, S8_Final_ACC, S9_Final_ACC, S10_Final_ACC]:
    ACC_z_median.append(num['x_axis'].median())

# %% [markdown]
# ## EDAの統計情報

# %%
S1_Final_EDA = S1_Final_EDA.set_axis(['EDA'], axis = 1)
S2_Final_EDA = S2_Final_EDA.set_axis(['EDA'], axis = 1)
S3_Final_EDA = S3_Final_EDA.set_axis(['EDA'], axis = 1)
S4_Final_EDA = S4_Final_EDA.set_axis(['EDA'], axis = 1)
S5_Final_EDA = S5_Final_EDA.set_axis(['EDA'], axis = 1)
S6_Final_EDA = S6_Final_EDA.set_axis(['EDA'], axis = 1)
S7_Final_EDA = S7_Final_EDA.set_axis(['EDA'], axis = 1)
S8_Final_EDA = S8_Final_EDA.set_axis(['EDA'], axis = 1)
S9_Final_EDA = S9_Final_EDA.set_axis(['EDA'], axis = 1)
S10_Final_EDA = S10_Final_EDA.set_axis(['EDA'], axis = 1)

# %%
S1_Final_EDA = S1_Final_EDA.drop(S1_Final_EDA.index[[0]])
S2_Final_EDA = S2_Final_EDA.drop(S2_Final_EDA.index[[0]])
S3_Final_EDA = S3_Final_EDA.drop(S3_Final_EDA.index[[0]])
S4_Final_EDA = S4_Final_EDA.drop(S4_Final_EDA.index[[0]])
S5_Final_EDA = S5_Final_EDA.drop(S5_Final_EDA.index[[0]])
S6_Final_EDA = S6_Final_EDA.drop(S6_Final_EDA.index[[0]])
S7_Final_EDA = S7_Final_EDA.drop(S7_Final_EDA.index[[0]])
S8_Final_EDA = S8_Final_EDA.drop(S8_Final_EDA.index[[0]])
S9_Final_EDA = S9_Final_EDA.drop(S9_Final_EDA.index[[0]])
S10_Final_EDA = S10_Final_EDA.drop(S10_Final_EDA.index[[0]])

# %%
EDA_max =[]
for num in [S1_Final_EDA, S2_Final_EDA, S3_Final_EDA, S4_Final_EDA, S5_Final_EDA, S6_Final_EDA, 
            S7_Final_EDA, S8_Final_EDA, S9_Final_EDA, S10_Final_EDA]:
    EDA_max.append(num['EDA'].max())

EDA_min =[]
for num in [S1_Final_EDA, S2_Final_EDA, S3_Final_EDA, S4_Final_EDA, S5_Final_EDA, S6_Final_EDA, 
            S7_Final_EDA, S8_Final_EDA, S9_Final_EDA, S10_Final_EDA]:
    EDA_min.append(num['EDA'].min())

EDA_mean =[]
for num in [S1_Final_EDA, S2_Final_EDA, S3_Final_EDA, S4_Final_EDA, S5_Final_EDA, S6_Final_EDA, 
            S7_Final_EDA, S8_Final_EDA, S9_Final_EDA, S10_Final_EDA]:
    EDA_mean.append(num['EDA'].mean())

EDA_std =[]
for num in [S1_Final_EDA, S2_Final_EDA, S3_Final_EDA, S4_Final_EDA, S5_Final_EDA, S6_Final_EDA, 
            S7_Final_EDA, S8_Final_EDA, S9_Final_EDA, S10_Final_EDA]:
    EDA_std.append(num['EDA'].std())

EDA_median =[]
for num in [S1_Final_EDA, S2_Final_EDA, S3_Final_EDA, S4_Final_EDA, S5_Final_EDA, S6_Final_EDA, 
            S7_Final_EDA, S8_Final_EDA, S9_Final_EDA, S10_Final_EDA]:
    EDA_median.append(num['EDA'].median())

# %% [markdown]
# ## HRの統計情報

# %%
S1_Final_HR = S1_Final_HR.set_axis(['HR'], axis = 1)
S2_Final_HR = S2_Final_HR.set_axis(['HR'], axis = 1)
S3_Final_HR = S3_Final_HR.set_axis(['HR'], axis = 1)
S4_Final_HR = S4_Final_HR.set_axis(['HR'], axis = 1)
S5_Final_HR = S5_Final_HR.set_axis(['HR'], axis = 1)
S6_Final_HR = S6_Final_HR.set_axis(['HR'], axis = 1)
S7_Final_HR = S7_Final_HR.set_axis(['HR'], axis = 1)
S8_Final_HR = S8_Final_HR.set_axis(['HR'], axis = 1)
S9_Final_HR = S9_Final_HR.set_axis(['HR'], axis = 1)
S10_Final_HR = S10_Final_HR.set_axis(['HR'], axis = 1)

# %%
S1_Final_HR = S1_Final_HR.drop(S1_Final_HR.index[[0]])
S2_Final_HR = S2_Final_HR.drop(S2_Final_HR.index[[0]])
S3_Final_HR = S3_Final_HR.drop(S3_Final_HR.index[[0]])
S4_Final_HR = S4_Final_HR.drop(S4_Final_HR.index[[0]])
S5_Final_HR = S5_Final_HR.drop(S5_Final_HR.index[[0]])
S6_Final_HR = S6_Final_HR.drop(S6_Final_HR.index[[0]])
S7_Final_HR = S7_Final_HR.drop(S7_Final_HR.index[[0]])
S8_Final_HR = S8_Final_HR.drop(S8_Final_HR.index[[0]])
S9_Final_HR = S9_Final_HR.drop(S9_Final_HR.index[[0]])
S10_Final_HR = S10_Final_HR.drop(S10_Final_HR.index[[0]])

# %%
HR_max =[]
for num in [S1_Final_HR, S2_Final_HR, S3_Final_HR, S4_Final_HR, S5_Final_HR, S6_Final_HR, 
            S7_Final_HR, S8_Final_HR, S9_Final_HR, S10_Final_HR]:
    HR_max.append(num['HR'].max())

HR_min =[]
for num in [S1_Final_HR, S2_Final_HR, S3_Final_HR, S4_Final_HR, S5_Final_HR, S6_Final_HR, 
            S7_Final_HR, S8_Final_HR, S9_Final_HR, S10_Final_HR]:
    HR_min.append(num['HR'].min())

HR_mean =[]
for num in [S1_Final_HR, S2_Final_HR, S3_Final_HR, S4_Final_HR, S5_Final_HR, S6_Final_HR, 
            S7_Final_HR, S8_Final_HR, S9_Final_HR, S10_Final_HR]:
    HR_mean.append(num['HR'].mean())

HR_std =[]
for num in [S1_Final_HR, S2_Final_HR, S3_Final_HR, S4_Final_HR, S5_Final_HR, S6_Final_HR, 
            S7_Final_HR, S8_Final_HR, S9_Final_HR, S10_Final_HR]:
    HR_std.append(num['HR'].std())

HR_median =[]
for num in [S1_Final_HR, S2_Final_HR, S3_Final_HR, S4_Final_HR, S5_Final_HR, S6_Final_HR, 
            S7_Final_HR, S8_Final_HR, S9_Final_HR, S10_Final_HR]:
    HR_median.append(num['HR'].median())

# %% [markdown]
# ## TEMPの統計情報

# %%
S1_Final_TEMP = S1_Final_TEMP.set_axis(['TEMP'], axis = 1)
S2_Final_TEMP = S2_Final_TEMP.set_axis(['TEMP'], axis = 1)
S3_Final_TEMP = S3_Final_TEMP.set_axis(['TEMP'], axis = 1)
S4_Final_TEMP = S4_Final_TEMP.set_axis(['TEMP'], axis = 1)
S5_Final_TEMP = S5_Final_TEMP.set_axis(['TEMP'], axis = 1)
S6_Final_TEMP = S6_Final_TEMP.set_axis(['TEMP'], axis = 1)
S7_Final_TEMP = S7_Final_TEMP.set_axis(['TEMP'], axis = 1)
S8_Final_TEMP = S8_Final_TEMP.set_axis(['TEMP'], axis = 1)
S9_Final_TEMP = S9_Final_TEMP.set_axis(['TEMP'], axis = 1)
S10_Final_TEMP= S10_Final_TEMP.set_axis(['TEMP'], axis = 1)

# %%
S1_Final_TEMP = S1_Final_TEMP.drop(S1_Final_TEMP.index[[0]])
S2_Final_TEMP = S2_Final_TEMP.drop(S2_Final_TEMP.index[[0]])
S3_Final_TEMP = S3_Final_TEMP.drop(S3_Final_TEMP.index[[0]])
S4_Final_TEMP = S4_Final_TEMP.drop(S4_Final_TEMP.index[[0]])
S5_Final_TEMP = S5_Final_TEMP.drop(S5_Final_TEMP.index[[0]])
S6_Final_TEMP = S6_Final_TEMP.drop(S6_Final_TEMP.index[[0]])
S7_Final_TEMP = S7_Final_TEMP.drop(S7_Final_TEMP.index[[0]])
S8_Final_TEMP = S8_Final_TEMP.drop(S8_Final_TEMP.index[[0]])
S9_Final_TEMP = S9_Final_TEMP.drop(S9_Final_TEMP.index[[0]])
S10_Final_TEMP = S10_Final_TEMP.drop(S10_Final_TEMP.index[[0]])

# %%
TEMP_max =[]
for num in [S1_Final_TEMP, S2_Final_TEMP, S3_Final_TEMP, S4_Final_TEMP, S5_Final_TEMP, S6_Final_TEMP, 
            S7_Final_TEMP, S8_Final_TEMP, S9_Final_TEMP, S10_Final_TEMP]:
    TEMP_max.append(num['TEMP'].max())

TEMP_min =[]
for num in [S1_Final_TEMP, S2_Final_TEMP, S3_Final_TEMP, S4_Final_TEMP, S5_Final_TEMP, S6_Final_TEMP, 
            S7_Final_TEMP, S8_Final_TEMP, S9_Final_TEMP, S10_Final_TEMP]:
    TEMP_min.append(num['TEMP'].min())

TEMP_mean =[]
for num in [S1_Final_TEMP, S2_Final_TEMP, S3_Final_TEMP, S4_Final_TEMP, S5_Final_TEMP, S6_Final_TEMP, 
            S7_Final_TEMP, S8_Final_TEMP, S9_Final_TEMP, S10_Final_TEMP]:
    TEMP_mean.append(num['TEMP'].mean())

TEMP_std =[]
for num in [S1_Final_TEMP, S2_Final_TEMP, S3_Final_TEMP, S4_Final_TEMP, S5_Final_TEMP, S6_Final_TEMP, 
            S7_Final_TEMP, S8_Final_TEMP, S9_Final_TEMP, S10_Final_TEMP]:
    TEMP_std.append(num['TEMP'].std())

TEMP_median =[]
for num in [S1_Final_TEMP, S2_Final_TEMP, S3_Final_TEMP, S4_Final_TEMP, S5_Final_TEMP, S6_Final_TEMP, 
            S7_Final_TEMP, S8_Final_TEMP, S9_Final_TEMP, S10_Final_TEMP]:
    TEMP_median.append(num['TEMP'].median())

# %% [markdown]
# # データフレーム作成

# %%
# ACC_*_max/minについては、すべて値が同一であったため、変数から外す
Student_list = ["S1", "S2", "S3", "S4", "S5", "S6", "S7", "S8", "S9", "S10"]


df_average = pd.DataFrame(Student_list, columns = ['Name'])
df_average['ACC_x_mean'] = ACC_x_mean
df_average['ACC_x_std'] = ACC_x_std
df_average['ACC_x_median'] = ACC_x_median
df_average['ACC_y_mean'] = ACC_y_mean
df_average['ACC_y_std'] = ACC_y_std
df_average['ACC_y_median'] = ACC_y_median
df_average['ACC_z_mean'] = ACC_z_mean
df_average['ACC_z_std'] = ACC_z_std
df_average['ACC_z_median'] = ACC_z_median
df_average['EDA_max'] = EDA_max
df_average['EDA_min'] = EDA_min
df_average['EDA_mean'] = EDA_mean
df_average['EDA_std'] = EDA_std
df_average['EDA_median'] = EDA_median
df_average['HR_max'] = HR_max
df_average['HR_min'] = HR_min
df_average['HR_mean'] = HR_mean
df_average['HR_std'] = HR_std
df_average['HR_median'] = HR_median
df_average['TEMP_max'] = TEMP_max
df_average['TEMP_min'] = TEMP_min
df_average['TEMP_mean'] = TEMP_mean
df_average['TEMP_std'] = TEMP_std
df_average['TEMP_median'] = TEMP_median

# %%
type(df_average)
# Out:
# pandas.core.frame.DataFrame

# %%
df_result = pd.DataFrame(df_average)

# %%
df_result
# Out:
#   Name  ACC_x_mean  ACC_x_std  ACC_x_median  ACC_y_mean  ACC_y_std  \
# 0   S1  -15.147696  33.683219    -15.147696  -15.147696  33.683219
# 1   S2  -36.306657  23.600241    -36.306657  -36.306657  23.600241
# 2   S3  -24.089768  30.544971    -24.089768  -24.089768  30.544971
# 3   S4  -32.685057  28.174360    -32.685057  -32.685057  28.174360
# 4   S5  -34.042692  34.210536    -34.042692  -34.042692  34.210536
# 5   S6  -25.022974  24.743804    -25.022974  -25.022974  24.743804
# 6   S7   15.516085  27.079422     15.516085   15.516085  27.079422
# 7   S8  -34.029859  25.763138    -34.029859  -34.029859  25.763138
# 8   S9  -43.029309  26.221102    -43.029309  -43.029309  26.221102
# 9  S10  -10.710487  37.080956    -10.710487  -10.710487  37.080956
#
#    ACC_y_median  ACC_z_mean  ACC_z_std  ACC_z_median  ...  HR_max  HR_min  \
# 0    -15.147696  -15.147696  33.683219          -7.0  ...  174.85   62.28
# 1    -36.306657  -36.306657  23.600241         -45.0  ...  201.67   69.80
# ...

# %%
df_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 25 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          10 non-null     object
#  1   ACC_x_mean    10 non-null     float64
#  2   ACC_x_std     10 non-null     float64
#  3   ACC_x_median  10 non-null     float64
#  4   ACC_y_mean    10 non-null     float64
#  5   ACC_y_std     10 non-null     float64
#  6   ACC_y_median  10 non-null     float64
#  7   ACC_z_mean    10 non-null     float64
#  8   ACC_z_std     10 non-null     float64
#  9   ACC_z_median  10 non-null     float64
#  10  EDA_max       10 non-null     float64
#  11  EDA_min       10 non-null     float64
#  12  EDA_mean      10 non-null     float64
#  13  EDA_std       10 non-null     float64
#  14  EDA_median    10 non-null     float64
#  15  HR_max        10 non-null     float64
#  16  HR_min        10 non-null     float64
# ...

# %% [markdown]
# # Dimension reduction using UMAP

# %%
# umapを用いて、data_matrixを2次元のデータに変換し、X_decompに結果を格納する。
# また、次元削減されたデータX_decompを可視化する。
def try_create_2d_umap(df, save_path, n_neighbors_list= [2, 4, 6]):
    fig, axes = plt.subplots(nrows=1, ncols=len(n_neighbors_list),figsize=(5*len(n_neighbors_list), 4))
    for i, (ax, n_neighbors) in enumerate(zip(axes.flatten(), n_neighbors_list)):
        mapper = umap.UMAP(n_components=2, random_state=0, n_neighbors=n_neighbors)
        X_decomp = mapper.fit_transform(df.values)
        ax.scatter(X_decomp[:, 0], X_decomp[:, 1])
        ax.set_title("n_neighbors_list: {}".format(n_neighbors))
    plt.savefig("{}/umap_search_n_neighbors.png".format(save_path))
    plt.show()
    
def main_umap(df, save_path, n_neighbors= 2):
    fig = plt.figure(figsize=(10,10))
    mapper = umap.UMAP(n_components=2, random_state=0, n_neighbors=n_neighbors)
    X_decomp = mapper.fit_transform(df.values)
    plt.scatter(X_decomp[:, 0], X_decomp[:, 1])
    plt.title("n_neighbors_list: {}".format(n_neighbors))
    plt.savefig("{}/umap_n_neighbors{}.png".format(save_path, n_neighbors))
    fig.show()
    np.save(os.path.join(save_path, 'decomp_1'), X_decomp[:,0])
    np.save(os.path.join(save_path, 'decomp_2'), X_decomp[:,1])
    return X_decomp

# %%
try_create_2d_umap(df_average.drop('Name', axis=1), save_path)
# Out:
# OMP: Info #276: omp_set_nested routine deprecated, please use omp_set_max_active_levels instead.

# %%
n_neighbors = 2
X_decomp = main_umap(df_average.drop('Name', axis=1), save_path, n_neighbors= n_neighbors)
# Out:
# /var/folders/pn/tp4rnlds5933mzdjzhq__0vw0000gn/T/ipykernel_95503/2644305465.py:20: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# # K-means Clustering

# %%
def scale_data(x):
    scaler = StandardScaler()
    scaler.fit(x)
    return scaler.transform(x)

def calculate_inertia(k, x) -> float:
    scaled_x = scale_data(x)
    model = KMeans(n_clusters=k)
    model.fit(scaled_x)
    return model.inertia_

inertias = [calculate_inertia(k, X_decomp) for k in range(2, 10)]
fig = plt.figure(figsize = (13,10))
sns.pointplot(x=list(range(2, 10)) ,y=inertias , linestyles ='--',markers = 'o',scale=1.5, color='#2ca02c')
sns.set(font_scale=1.3)
plt.title('Inertia Vs K')
plt.xlabel('K')
plt.ylabel('Inertia')
plt.show()

fig.savefig("{}/elbor_plot_n2.png".format(save_path))

# %%
def kmeans_data(x, save_path, k):

    fig = plt.figure(figsize=(10,10))
    ax = fig.add_subplot(1,1,1)


    # 次元削減したデータX_decompを用いて、クラスタリングする。
    # なお、クラスタリングにはscikit-learnのK-meansを用いる。

    scaled_x = scale_data(x)
    model = KMeans(n_clusters=k)
    model.fit(scaled_x)
    label_values_ind = model.labels_
    label_values_unique = np.unique(label_values_ind)

    cluster_centers_ind = model.cluster_centers_
    colors = cm.prism(np.linspace(0, 1, len(label_values_unique)))
    sns.scatterplot(x=scaled_x[:,0], y=scaled_x[:,1], hue=label_values_ind, palette='bright', sizes=200)
    sns.set_style(style=None, rc=None)
    
    
    plt.legend()
    fig.show()
    return label_values_ind

# %%
k=3  # The number of cluster
label_values_ind = kmeans_data(X_decomp, save_path, k=k)
df_average['labels'] = label_values_ind


# ここで、df_averageの結果をcsvファイルに格納。
df_average.to_csv("{}/result_n2.csv".format(save_path), index=False)
df_average
# Out:
# /var/folders/pn/tp4rnlds5933mzdjzhq__0vw0000gn/T/ipykernel_95503/451524087.py:23: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
#   Name  ACC_x_mean  ACC_x_std  ACC_x_median  ACC_y_mean  ACC_y_std  \
# 0   S1  -15.147696  33.683219    -15.147696  -15.147696  33.683219
# 1   S2  -36.306657  23.600241    -36.306657  -36.306657  23.600241
# 2   S3  -24.089768  30.544971    -24.089768  -24.089768  30.544971
# 3   S4  -32.685057  28.174360    -32.685057  -32.685057  28.174360
# 4   S5  -34.042692  34.210536    -34.042692  -34.042692  34.210536
# 5   S6  -25.022974  24.743804    -25.022974  -25.022974  24.743804
# 6   S7   15.516085  27.079422     15.516085   15.516085  27.079422
# 7   S8  -34.029859  25.763138    -34.029859  -34.029859  25.763138
# 8   S9  -43.029309  26.221102    -43.029309  -43.029309  26.221102
# ...

# %% [markdown]
# # Show features for each cluster

# %%
def boxplot_cluster(df, save_path):
    col_list = df.columns.values[df.columns.str.contains('mean')]
    fig = plt.figure(figsize=(10,10))
    for i, col in enumerate(col_list):
        ax = fig.add_subplot(2, 3, i+1)
        sns.boxplot(x='labels', y=col, data=df, ax=ax)
        ax.set_ylabel(col)
    # show plots
    fig.tight_layout()
    fig.savefig("{}/boxplot_cluster_n2.png".format(save_path))
    fig.show()

# %%
boxplot_cluster(df_average, save_path)
# Out:
# /var/folders/pn/tp4rnlds5933mzdjzhq__0vw0000gn/T/ipykernel_95503/3487783635.py:11: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# ## 散布図に生徒識別子、得点をラベリング

# %%
Gradelist = [182, 180, 188, 149, 157, 175, 110, 184, 126, 116]
labels = df_average["labels"]
NameGrade = ["S1: 182", "S2: 180", "S3: 188", "S4: 149", "S5: 157", "S6: 175", "S7: 110", "S8: 184", "S9: 126", "S10: 116"]

# %%
df_decomp = pd.DataFrame(X_decomp)
df_decomp['Name'] = Student_list
df_decomp['grade'] = Gradelist
df_decomp["Name + Grade"] = NameGrade
df_decomp['cluster'] = labels
df_decomp
# Out:
#            0          1 Name  grade Name + Grade  cluster
# 0  18.114727   9.095153   S1    182      S1: 182        1
# 1 -12.624319   9.629323   S2    180      S2: 180        0
# 2  -6.015306   6.307841   S3    188      S3: 188        2
# 3 -13.188318  10.050385   S4    149      S4: 149        0
# 4 -11.593534  10.283964   S5    157      S5: 157        0
# 5  -6.302150   6.593732   S6    175      S6: 175        2
# 6  17.659477   9.550374   S7    110      S7: 110        1
# 7 -12.725999  10.298177   S8    184      S8: 184        0
# 8 -12.032003  10.360954   S9    126      S9: 126        0
# 9  17.392523   9.817700  S10    116     S10: 116        1

# %%
def label_point(x,y,id,ax):
  df_tmp=pd.concat({'x':x,'y':y,'id':id}, axis='columns')
  for i, point in df_tmp.iterrows():
    ax.text(point['x'], point['y'], point['id'],\
    fontsize=15\
    )
    


fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(1,1,1)

label_values_ind = df_decomp["cluster"]
label_values_unique = np.unique(label_values_ind)

colors = cm.prism(np.linspace(0, 1, len(label_values_unique)))
figure = sns.scatterplot(x=df_decomp[0], y=df_decomp[1], hue=label_values_ind, palette='bright', sizes=200)
label_point(df_decomp[0], df_decomp[1], df_decomp["Name + Grade"],ax)
        
fig.show(figure)
plt.savefig(os.path.join(save_path, 'kmeans_fig_n2.png'))
# Out:
# /var/folders/pn/tp4rnlds5933mzdjzhq__0vw0000gn/T/ipykernel_95503/4218506436.py:20: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show(figure)

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.subplots(1, 1)
sns.boxplot(x=df_decomp["cluster"], y=df_decomp["grade"], ax=ax)
ax.set_ylabel("Grade")
fig.tight_layout()
fig.savefig("{}/boxplot_grade_n2.png".format(save_path))
fig.show()
# Out:
# /var/folders/pn/tp4rnlds5933mzdjzhq__0vw0000gn/T/ipykernel_95503/884350277.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %% [markdown]
# # n = 4

# %%
n_neighbors = 4
X_decomp = main_umap(df_average.drop('Name', axis=1), save_path, n_neighbors= n_neighbors)

def scale_data(x):
    scaler = StandardScaler()
    scaler.fit(x)
    return scaler.transform(x)

def calculate_inertia(k, x) -> float:
    scaled_x = scale_data(x)
    model = KMeans(n_clusters=k)
    model.fit(scaled_x)
    return model.inertia_

inertias = [calculate_inertia(k, X_decomp) for k in range(2, 10)]
plt.figure(figsize = (13,10))
sns.pointplot(x=list(range(2, 10)) ,y=inertias , linestyles ='--',markers = 'o',scale=1.5, color='#2ca02c')
sns.set(font_scale=1.3)
plt.title('Inertia Vs K')
plt.xlabel('K')
plt.ylabel('Inertia')
plt.show()

k=3 # The number of cluster
label_values_ind = kmeans_data(X_decomp, save_path, k=k)
df_average['labels'] = label_values_ind


# ここで、df_averageの結果をcsvファイルに格納。
df_average.to_csv("{}/result_n4.csv".format(save_path), index=False)
df_average

def boxplot_cluster(df, save_path):
    col_list = df.columns.values[df.columns.str.contains('mean')]
    fig = plt.figure(figsize=(10,10))
    for i, col in enumerate(col_list):
        ax = fig.add_subplot(2, 3, i+1)
        sns.boxplot(x='labels', y=col, data=df, ax=ax)
        ax.set_ylabel(col)
    # show plots
    fig.tight_layout()
    fig.savefig("{}/boxplot_cluster_n4.png".format(save_path))
    fig.show()
    
boxplot_cluster(df_average, save_path)
    
Gradelist = [182, 180, 188, 149, 157, 175, 110, 184, 126, 116]
labels = df_average["labels"]
NameGrade = ["S1: 182", "S2: 180", "S3: 188", "S4: 149", "S5: 157", "S6: 175", "S7: 110", "S8: 184", "S9: 126", "S10: 116"]

df_decomp = pd.DataFrame(X_decomp)
df_decomp['Name'] = Student_list
df_decomp['grade'] = Gradelist
df_decomp["Name + Grade"] = NameGrade
df_decomp['cluster'] = labels
df_decomp

def label_point(x,y,id,ax):
  df_tmp=pd.concat({'x':x,'y':y,'id':id}, axis='columns')
  for i, point in df_tmp.iterrows():
    ax.text(point['x'], point['y'], point['id'],\
    fontsize=15\
    )

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(1,1,1)

label_values_ind = df_decomp["cluster"]
label_values_unique = np.unique(label_values_ind)

colors = cm.prism(np.linspace(0, 1, len(label_values_unique)))
figure = sns.scatterplot(x=df_decomp[0], y=df_decomp[1], hue=label_values_ind, palette='bright', sizes=200)
label_point(df_decomp[0], df_decomp[1], df_decomp["Name + Grade"],ax)
        
fig.show(figure)
plt.savefig(os.path.join(save_path, 'kmeans_fig_n4.png'))

fig = plt.figure(figsize=(10,10))
ax = fig.subplots(1, 1)
sns.boxplot(x=df_decomp["cluster"], y=df_decomp["grade"], ax=ax)
ax.set_ylabel("Grade")
fig.tight_layout()
fig.savefig("{}/boxplot_grade_n４.png".format(save_path))
fig.show()
# Out:
# /var/folders/pn/tp4rnlds5933mzdjzhq__0vw0000gn/T/ipykernel_95503/2644305465.py:20: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /var/folders/pn/tp4rnlds5933mzdjzhq__0vw0000gn/T/ipykernel_95503/451524087.py:23: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /var/folders/pn/tp4rnlds5933mzdjzhq__0vw0000gn/T/ipykernel_95503/1196725991.py:43: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /var/folders/pn/tp4rnlds5933mzdjzhq__0vw0000gn/T/ipykernel_95503/1196725991.py:75: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show(figure)
# ...

# %% [markdown]
# # n = 6

# %%
n_neighbors = 6
X_decomp = main_umap(df_average.drop('Name', axis=1), save_path, n_neighbors= n_neighbors)

def scale_data(x):
    scaler = StandardScaler()
    scaler.fit(x)
    return scaler.transform(x)

def calculate_inertia(k, x) -> float:
    scaled_x = scale_data(x)
    model = KMeans(n_clusters=k)
    model.fit(scaled_x)
    return model.inertia_

inertias = [calculate_inertia(k, X_decomp) for k in range(2, 10)]
plt.figure(figsize = (13,10))
sns.pointplot(x=list(range(2, 10)) ,y=inertias , linestyles ='--',markers = 'o',scale=1.5, color='#2ca02c')
sns.set(font_scale=1.3)
plt.title('Inertia Vs K')
plt.xlabel('K')
plt.ylabel('Inertia')
plt.show()

k=3  # The number of cluster
label_values_ind = kmeans_data(X_decomp, save_path, k=k)
df_average['labels'] = label_values_ind


# ここで、df_averageの結果をcsvファイルに格納。
df_average.to_csv("{}/result_n6.csv".format(save_path), index=False)
df_average

def boxplot_cluster(df, save_path):
    col_list = df.columns.values[df.columns.str.contains('mean')]
    fig = plt.figure(figsize=(10,10))
    for i, col in enumerate(col_list):
        ax = fig.add_subplot(2, 3, i+1)
        sns.boxplot(x='labels', y=col, data=df, ax=ax)
        ax.set_ylabel(col)
    # show plots
    fig.tight_layout()
    fig.savefig("{}/boxplot_cluster_n6.png".format(save_path))
    fig.show()
    
boxplot_cluster(df_average, save_path)

Gradelist = [182, 180, 188, 149, 157, 175, 110, 184, 126, 116]
labels = df_average["labels"]
NameGrade = ["S1: 182", "S2: 180", "S3: 188", "S4: 149", "S5: 157", "S6: 175", "S7: 110", "S8: 184", "S9: 126", "S10: 116"]

df_decomp = pd.DataFrame(X_decomp)
df_decomp['Name'] = Student_list
df_decomp['grade'] = Gradelist
df_decomp["Name + Grade"] = NameGrade
df_decomp['cluster'] = labels
df_decomp

def label_point(x,y,id,ax):
  df_tmp=pd.concat({'x':x,'y':y,'id':id}, axis='columns')
  for i, point in df_tmp.iterrows():
    ax.text(point['x'], point['y'], point['id'],\
    fontsize=15\
    )

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(1,1,1)

label_values_ind = df_decomp["cluster"]
label_values_unique = np.unique(label_values_ind)

colors = cm.prism(np.linspace(0, 1, len(label_values_unique)))
figure = sns.scatterplot(x=df_decomp[0], y=df_decomp[1], hue=label_values_ind, palette='bright', sizes=200)
label_point(df_decomp[0], df_decomp[1], df_decomp["Name + Grade"],ax)
        
fig.show(figure)
plt.savefig(os.path.join(save_path, 'kmeans_fig_n6.png'))

fig = plt.figure(figsize=(10,10))
ax = fig.subplots(1, 1)
sns.boxplot(x=df_decomp["cluster"], y=df_decomp["grade"], ax=ax)
ax.set_ylabel("Grade")
fig.tight_layout()
fig.savefig("{}/boxplot_grade_n6.png".format(save_path))
fig.show()
# Out:
# /var/folders/pn/tp4rnlds5933mzdjzhq__0vw0000gn/T/ipykernel_95503/2644305465.py:20: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /var/folders/pn/tp4rnlds5933mzdjzhq__0vw0000gn/T/ipykernel_95503/451524087.py:23: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /var/folders/pn/tp4rnlds5933mzdjzhq__0vw0000gn/T/ipykernel_95503/4129931203.py:43: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /var/folders/pn/tp4rnlds5933mzdjzhq__0vw0000gn/T/ipykernel_95503/4129931203.py:75: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show(figure)
# ...

# %% [markdown]
# # n = 8

# %%
n_neighbors = 8
X_decomp = main_umap(df_average.drop('Name', axis=1), save_path, n_neighbors= n_neighbors)

def scale_data(x):
    scaler = StandardScaler()
    scaler.fit(x)
    return scaler.transform(x)

def calculate_inertia(k, x) -> float:
    scaled_x = scale_data(x)
    model = KMeans(n_clusters=k)
    model.fit(scaled_x)
    return model.inertia_

inertias = [calculate_inertia(k, X_decomp) for k in range(2, 10)]
plt.figure(figsize = (13,10))
sns.pointplot(x=list(range(2, 10)) ,y=inertias , linestyles ='--',markers = 'o',scale=1.5, color='#2ca02c')
sns.set(font_scale=1.3)
plt.title('Inertia Vs K')
plt.xlabel('K')
plt.ylabel('Inertia')
plt.show()

k=3  # The number of cluster
label_values_ind = kmeans_data(X_decomp, save_path, k=k)
df_average['labels'] = label_values_ind


# ここで、df_averageの結果をcsvファイルに格納。
df_average.to_csv("{}/result_n8.csv".format(save_path), index=False)
df_average

def boxplot_cluster(df, save_path):
    col_list = df.columns.values[df.columns.str.contains('mean')]
    fig = plt.figure(figsize=(10,10))
    for i, col in enumerate(col_list):
        ax = fig.add_subplot(2, 3, i+1)
        sns.boxplot(x='labels', y=col, data=df, ax=ax)
        ax.set_ylabel(col)
    # show plots
    fig.tight_layout()
    fig.savefig("{}/boxplot_cluster_n8.png".format(save_path))
    fig.show()
    
boxplot_cluster(df_average, save_path)

Gradelist = [182, 180, 188, 149, 157, 175, 110, 184, 126, 116]
labels = df_average["labels"]
NameGrade = ["S1: 182", "S2: 180", "S3: 188", "S4: 149", "S5: 157", "S6: 175", "S7: 110", "S8: 184", "S9: 126", "S10: 116"]

df_decomp = pd.DataFrame(X_decomp)
df_decomp['Name'] = Student_list
df_decomp['grade'] = Gradelist
df_decomp["Name + Grade"] = NameGrade
df_decomp['cluster'] = labels
df_decomp

def label_point(x,y,id,ax):
  df_tmp=pd.concat({'x':x,'y':y,'id':id}, axis='columns')
  for i, point in df_tmp.iterrows():
    ax.text(point['x'], point['y'], point['id'],\
    fontsize=15\
    )

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(1,1,1)

label_values_ind = df_decomp["cluster"]
label_values_unique = np.unique(label_values_ind)

colors = cm.prism(np.linspace(0, 1, len(label_values_unique)))
figure = sns.scatterplot(x=df_decomp[0], y=df_decomp[1], hue=label_values_ind, palette='bright', sizes=200)
label_point(df_decomp[0], df_decomp[1], df_decomp["Name + Grade"],ax)
        
fig.show(figure)
plt.savefig(os.path.join(save_path, 'kmeans_fig_n8.png'))

fig = plt.figure(figsize=(10,10))
ax = fig.subplots(1, 1)
sns.boxplot(x=df_decomp["cluster"], y=df_decomp["grade"], ax=ax)
ax.set_ylabel("Grade")
fig.tight_layout()
fig.savefig("{}/boxplot_grade_n8.png".format(save_path))
fig.show()
# Out:
# /var/folders/pn/tp4rnlds5933mzdjzhq__0vw0000gn/T/ipykernel_95503/2644305465.py:20: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /var/folders/pn/tp4rnlds5933mzdjzhq__0vw0000gn/T/ipykernel_95503/451524087.py:23: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /var/folders/pn/tp4rnlds5933mzdjzhq__0vw0000gn/T/ipykernel_95503/2277723523.py:43: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# /var/folders/pn/tp4rnlds5933mzdjzhq__0vw0000gn/T/ipykernel_95503/2277723523.py:75: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show(figure)
# ...
